# %% [markdown]
# <a href="https://colab.research.google.com/github/KARANGULABASANTH/NASSCOM/blob/main/NasscomDay_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# # 1)
# a=25
# b=30
# print(a+b)

# #2)
# a=25
# b=30
# print(a*b)
# print(a-b)

# # 3)
# a=25
# b=30
# print(a/b)

# # 4)
# for i in range (1,11):
#   print(2*i)

# # 5)
# a=int(input())
# b=int(input())
# n=int(input())
# for i in range (1,n+1):
#   if i==1:
#     print(a,end=" ")
#   elif i==2:
#     print(b,end=" ")
#   else:
#     c=a+b
#     print(c,end=" ")
#     a=b
#     b=c

# # 6)
# # a)
# a=7
# print(type(a))

# # 6)
# # b)
# b=2.5
# print(type(b))

# # 6)c)
# c="2+3j"
# print(type(c))

# # 6)d)
# a=True
# print(type(a))

# # 6)e)
# b=False
# type(b)


# import math
# print(math.pi)

# import math;
# print(math.exp(10))

# import math;
# print(math.cos(math.pi))

# import math
# print(math.asin(1))

# import math
# print(math.cosh(1))

# import math
# print(math.sinh(1))

# import math
# print(math.tanh(1))
# Out:
# 0.7615941559557649
